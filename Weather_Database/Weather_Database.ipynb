# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Weather": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | quatre cocos
# Processing Record 2 of Set 1 | lorengau
# Processing Record 3 of Set 1 | kineshma
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | martapura
# Processing Record 6 of Set 1 | acapulco
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | hofn
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | ngunguru
# Processing Record 11 of Set 1 | inverness
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | havre-saint-pierre
# Processing Record 14 of Set 1 | marsh harbour
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | ribeira brava
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | haikou
# Processing Record 22 of Set 1 | chenzhou
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | koceljeva
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | garoua
# Processing Record 32 of Set 1 | samarai
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | salalah
# Processing Record 35 of Set 1 | alta floresta
# Processing Record 36 of Set 1 | biltine
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | afyonkarahisar
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | aklavik
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | berlevag
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | kazachinskoye
# Processing Record 49 of Set 1 | gboko
# Processing Record 50 of Set 1 | the valley
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | broome
# Processing Record 3 of Set 2 | siljan
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | linxia
# Processing Record 7 of Set 2 | kahului
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | rocha
# Processing Record 13 of Set 2 | esperance
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | caravelas
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | opuwo
# Processing Record 20 of Set 2 | san quintin
# Processing Record 21 of Set 2 | berlin
# Processing Record 22 of Set 2 | fier
# Processing Record 23 of Set 2 | barcelona
# Processing Record 24 of Set 2 | murray bridge
# Processing Record 25 of Set 2 | harindanga
# Processing Record 26 of Set 2 | mocuba
# Processing Record 27 of Set 2 | flinders
# Processing Record 28 of Set 2 | ballina
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | boa vista
# Processing Record 31 of Set 2 | yabassi
# Processing Record 32 of Set 2 | wakkanai
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | rawson
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | amot
# Processing Record 39 of Set 2 | beloha
# Processing Record 40 of Set 2 | hovd
# Processing Record 41 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 2 | constitucion
# Processing Record 43 of Set 2 | yulara
# Processing Record 44 of Set 2 | haines junction
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | graneros
# Processing Record 48 of Set 2 | bakchar
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | jumla
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | chubbuck
# Processing Record 4 of Set 3 | bandarbeyla
# Processing Record 5 of Set 3 | talnakh
# Processing Record 6 of Set 3 | nikolskoye
# Processing Record 7 of Set 3 | grand gaube
# Processing Record 8 of Set 3 | tanete
# Processing Record 9 of Set 3 | nuristan
# Processing Record 10 of Set 3 | revelstoke
# Processing Record 11 of Set 3 | naze
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | pryazha
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | miles city
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | marrakesh
# Processing Record 23 of Set 3 | berdyuzhye
# City not found. Skipping...
# Processing Record 24 of Set 3 | ayagoz
# Processing Record 25 of Set 3 | westport
# Processing Record 26 of Set 3 | port moresby
# Processing Record 27 of Set 3 | palmer
# Processing Record 28 of Set 3 | lasa
# Processing Record 29 of Set 3 | waddan
# Processing Record 30 of Set 3 | santiago de cao
# Processing Record 31 of Set 3 | bonfim
# Processing Record 32 of Set 3 | omboue
# Processing Record 33 of Set 3 | visby
# Processing Record 34 of Set 3 | port augusta
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 37 of Set 3 | la ronge
# Processing Record 38 of Set 3 | ramhormoz
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | cabedelo
# Processing Record 41 of Set 3 | leningradskiy
# Processing Record 42 of Set 3 | bowen
# Processing Record 43 of Set 3 | kavieng
# Processing Record 44 of Set 3 | arlit
# Processing Record 45 of Set 3 | vaini
# Processing Record 46 of Set 3 | barrow
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | manakara
# Processing Record 49 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 3 | torit
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | hualmay
# Processing Record 3 of Set 4 | erzin
# Processing Record 4 of Set 4 | geraldton
# Processing Record 5 of Set 4 | upernavik
# Processing Record 6 of Set 4 | asau
# Processing Record 7 of Set 4 | coahuayana
# Processing Record 8 of Set 4 | marzuq
# Processing Record 9 of Set 4 | raudeberg
# Processing Record 10 of Set 4 | zonalnoye
# City not found. Skipping...
# Processing Record 11 of Set 4 | yaan
# Processing Record 12 of Set 4 | slave lake
# Processing Record 13 of Set 4 | altay
# Processing Record 14 of Set 4 | springdale
# Processing Record 15 of Set 4 | brae
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | cabo san lucas
# Processing Record 18 of Set 4 | anchorage
# Processing Record 19 of Set 4 | atar
# Processing Record 20 of Set 4 | kushiro
# Processing Record 21 of Set 4 | port hedland
# Processing Record 22 of Set 4 | port macquarie
# Processing Record 23 of Set 4 | jamestown
# Processing Record 24 of Set 4 | batemans bay
# Processing Record 25 of Set 4 | cape town
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | oranjemund
# Processing Record 28 of Set 4 | celestun
# Processing Record 29 of Set 4 | babu
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | pochutla
# Processing Record 32 of Set 4 | coihaique
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 4 | bonga
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | clyde river
# Processing Record 39 of Set 4 | conde
# Processing Record 40 of Set 4 | mackay
# Processing Record 41 of Set 4 | oktyabrskoye
# Processing Record 42 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 4 | ossora
# Processing Record 44 of Set 4 | agirish
# Processing Record 45 of Set 4 | oyama
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | kenora
# Processing Record 48 of Set 4 | punta alta
# Processing Record 49 of Set 4 | nangomba
# Processing Record 50 of Set 4 | mala
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | ranong
# Processing Record 3 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 5 | sesheke
# Processing Record 5 of Set 5 | neiafu
# Processing Record 6 of Set 5 | kawalu
# Processing Record 7 of Set 5 | barstow
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | ekhabi
# Processing Record 10 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 5 | lerwick
# Processing Record 12 of Set 5 | yafran
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | saint-augustin
# Processing Record 15 of Set 5 | vanimo
# Processing Record 16 of Set 5 | margate
# Processing Record 17 of Set 5 | waldkirchen
# Processing Record 18 of Set 5 | guantanamo
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | am timan
# Processing Record 21 of Set 5 | klaksvik
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | donskoye
# Processing Record 24 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 5 | morondava
# Processing Record 26 of Set 5 | mongo
# Processing Record 27 of Set 5 | nanyang
# Processing Record 28 of Set 5 | yelizovo
# Processing Record 29 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 5 | hamilton
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | soyo
# Processing Record 33 of Set 5 | iquique
# Processing Record 34 of Set 5 | we
# City not found. Skipping...
# Processing Record 35 of Set 5 | alofi
# Processing Record 36 of Set 5 | port elizabeth
# Processing Record 37 of Set 5 | lavrentiya
# Processing Record 38 of Set 5 | saint-joseph
# Processing Record 39 of Set 5 | odweyne
# Processing Record 40 of Set 5 | bocaiuva
# Processing Record 41 of Set 5 | aviles
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | marawi
# Processing Record 44 of Set 5 | san jeronimo
# Processing Record 45 of Set 5 | skovde
# City not found. Skipping...
# Processing Record 46 of Set 5 | melipilla
# Processing Record 47 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 48 of Set 5 | moroto
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 50 of Set 5 | olga
# Processing Record 1 of Set 6 | ribeira grande
# Processing Record 2 of Set 6 | killam
# Processing Record 3 of Set 6 | flin flon
# Processing Record 4 of Set 6 | khorramshahr
# Processing Record 5 of Set 6 | kiunga
# Processing Record 6 of Set 6 | ketchikan
# Processing Record 7 of Set 6 | cairns
# Processing Record 8 of Set 6 | ouadda
# Processing Record 9 of Set 6 | necochea
# Processing Record 10 of Set 6 | simbahan
# Processing Record 11 of Set 6 | oktyabrskiy
# Processing Record 12 of Set 6 | carnarvon
# Processing Record 13 of Set 6 | miquelon
# Processing Record 14 of Set 6 | ostrovnoy
# Processing Record 15 of Set 6 | torbeyevo
# Processing Record 16 of Set 6 | guerrero
# Processing Record 17 of Set 6 | borgarnes
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | bethanien
# Processing Record 20 of Set 6 | tevaitoa
# Processing Record 21 of Set 6 | riyadh
# Processing Record 22 of Set 6 | cravo norte
# Processing Record 23 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 24 of Set 6 | lebanon
# Processing Record 25 of Set 6 | severo-kurilsk
# Processing Record 26 of Set 6 | ancud
# Processing Record 27 of Set 6 | voyvozh
# Processing Record 28 of Set 6 | rabo de peixe
# Processing Record 29 of Set 6 | fushun
# Processing Record 30 of Set 6 | castro
# Processing Record 31 of Set 6 | miandoab
# Processing Record 32 of Set 6 | nueva loja
# Processing Record 33 of Set 6 | fougeres
# Processing Record 34 of Set 6 | saint-pierre
# Processing Record 35 of Set 6 | college
# Processing Record 36 of Set 6 | pimenta bueno
# Processing Record 37 of Set 6 | schwarzenberg
# Processing Record 38 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 6 | san cristobal
# Processing Record 40 of Set 6 | mount gambier
# Processing Record 41 of Set 6 | bacalar
# Processing Record 42 of Set 6 | ashtabula
# Processing Record 43 of Set 6 | randfontein
# Processing Record 44 of Set 6 | yumen
# Processing Record 45 of Set 6 | mancio lima
# Processing Record 46 of Set 6 | shimoda
# Processing Record 47 of Set 6 | fort nelson
# Processing Record 48 of Set 6 | kudahuvadhoo
# Processing Record 49 of Set 6 | kijang
# Processing Record 50 of Set 6 | vila velha
# Processing Record 1 of Set 7 | biak
# Processing Record 2 of Set 7 | metro
# Processing Record 3 of Set 7 | anadyr
# Processing Record 4 of Set 7 | bay roberts
# Processing Record 5 of Set 7 | hithadhoo
# Processing Record 6 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 7 | qostanay
# Processing Record 8 of Set 7 | santa maria da boa vista
# Processing Record 9 of Set 7 | bantry
# Processing Record 10 of Set 7 | deputatskiy
# Processing Record 11 of Set 7 | talaya
# Processing Record 12 of Set 7 | cherskiy
# Processing Record 13 of Set 7 | wanning
# Processing Record 14 of Set 7 | nakonde
# Processing Record 15 of Set 7 | santa cruz del sur
# Processing Record 16 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 7 | ramnagar
# Processing Record 18 of Set 7 | nipawin
# Processing Record 19 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 7 | senanga
# Processing Record 21 of Set 7 | plainview
# Processing Record 22 of Set 7 | suntar
# Processing Record 23 of Set 7 | creston
# Processing Record 24 of Set 7 | schitu
# Processing Record 25 of Set 7 | arrifes
# Processing Record 26 of Set 7 | yerbogachen
# Processing Record 27 of Set 7 | oistins
# Processing Record 28 of Set 7 | kanniyakumari
# Processing Record 29 of Set 7 | inuvik
# Processing Record 30 of Set 7 | jalu
# Processing Record 31 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 7 | coquimbo
# Processing Record 34 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 7 | port lincoln
# Processing Record 36 of Set 7 | khorol
# Processing Record 37 of Set 7 | tilichiki
# Processing Record 38 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 7 | suarez
# Processing Record 40 of Set 7 | los lunas
# Processing Record 41 of Set 7 | shelburne
# Processing Record 42 of Set 7 | tateyama
# Processing Record 43 of Set 7 | miracema do tocantins
# Processing Record 44 of Set 7 | cascais
# Processing Record 45 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 7 | lokoja
# Processing Record 47 of Set 7 | maicao
# Processing Record 48 of Set 7 | talara
# Processing Record 49 of Set 7 | cidreira
# Processing Record 50 of Set 7 | nouadhibou
# Processing Record 1 of Set 8 | gushikawa
# Processing Record 2 of Set 8 | sidi ali
# Processing Record 3 of Set 8 | makaryev
# Processing Record 4 of Set 8 | nyurba
# Processing Record 5 of Set 8 | mayo
# Processing Record 6 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 7 of Set 8 | saveh
# Processing Record 8 of Set 8 | la romana
# Processing Record 9 of Set 8 | lazaro cardenas
# Processing Record 10 of Set 8 | port hardy
# Processing Record 11 of Set 8 | dhidhdhoo
# Processing Record 12 of Set 8 | mikhaylovka
# Processing Record 13 of Set 8 | pimentel
# Processing Record 14 of Set 8 | tshikapa
# Processing Record 15 of Set 8 | sinnamary
# Processing Record 16 of Set 8 | hambantota
# Processing Record 17 of Set 8 | kilmallock
# Processing Record 18 of Set 8 | takab
# Processing Record 19 of Set 8 | mahebourg
# Processing Record 20 of Set 8 | neverkino
# Processing Record 21 of Set 8 | tomatlan
# Processing Record 22 of Set 8 | ushtobe
# Processing Record 23 of Set 8 | brzeg dolny
# Processing Record 24 of Set 8 | shakawe
# Processing Record 25 of Set 8 | bilma
# Processing Record 26 of Set 8 | sao francisco do sul
# Processing Record 27 of Set 8 | srivardhan
# Processing Record 28 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 8 | ixtapa
# Processing Record 30 of Set 8 | wasilla
# Processing Record 31 of Set 8 | vostok
# Processing Record 32 of Set 8 | touros
# Processing Record 33 of Set 8 | arraial do cabo
# Processing Record 34 of Set 8 | puebloviejo
# Processing Record 35 of Set 8 | birao
# Processing Record 36 of Set 8 | colac
# Processing Record 37 of Set 8 | qaqortoq
# Processing Record 38 of Set 8 | chokurdakh
# Processing Record 39 of Set 8 | nabire
# Processing Record 40 of Set 8 | henties bay
# Processing Record 41 of Set 8 | yaring
# Processing Record 42 of Set 8 | poum
# Processing Record 43 of Set 8 | portland
# Processing Record 44 of Set 8 | batsfjord
# Processing Record 45 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 46 of Set 8 | galveston
# Processing Record 47 of Set 8 | gat
# Processing Record 48 of Set 8 | northam
# Processing Record 49 of Set 8 | ahipara
# Processing Record 50 of Set 8 | praia
# Processing Record 1 of Set 9 | kosikha
# Processing Record 2 of Set 9 | thompson
# Processing Record 3 of Set 9 | ternate
# Processing Record 4 of Set 9 | lazarev
# Processing Record 5 of Set 9 | axim
# Processing Record 6 of Set 9 | jorochito
# Processing Record 7 of Set 9 | yinchuan
# Processing Record 8 of Set 9 | mumford
# Processing Record 9 of Set 9 | zarautz
# Processing Record 10 of Set 9 | kovdor
# Processing Record 11 of Set 9 | monrovia
# Processing Record 12 of Set 9 | kathu
# Processing Record 13 of Set 9 | ulan-ude
# Processing Record 14 of Set 9 | guerrero negro
# Processing Record 15 of Set 9 | lagoa
# Processing Record 16 of Set 9 | sao gabriel da cachoeira
# Processing Record 17 of Set 9 | kikwit
# Processing Record 18 of Set 9 | nome
# Processing Record 19 of Set 9 | verkhniy fiagdon
# Processing Record 20 of Set 9 | lewistown
# Processing Record 21 of Set 9 | lompoc
# Processing Record 22 of Set 9 | pangody
# Processing Record 23 of Set 9 | dawlatabad
# Processing Record 24 of Set 9 | goianinha
# Processing Record 25 of Set 9 | usinsk
# Processing Record 26 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 9 | san francisco
# Processing Record 28 of Set 9 | punta de bombon
# Processing Record 29 of Set 9 | la vergne
# Processing Record 30 of Set 9 | kibaya
# Processing Record 31 of Set 9 | sao joao do piaui
# Processing Record 32 of Set 9 | havoysund
# Processing Record 33 of Set 9 | dunedin
# Processing Record 34 of Set 9 | tampakan
# Processing Record 35 of Set 9 | nhulunbuy
# Processing Record 36 of Set 9 | rosolini
# Processing Record 37 of Set 9 | zaozhuang
# Processing Record 38 of Set 9 | abu dhabi
# Processing Record 39 of Set 9 | sechura
# Processing Record 40 of Set 9 | lugo
# Processing Record 41 of Set 9 | kaeo
# Processing Record 42 of Set 9 | gazojak
# Processing Record 43 of Set 9 | nouakchott
# Processing Record 44 of Set 9 | rorvik
# Processing Record 45 of Set 9 | antofagasta
# Processing Record 46 of Set 9 | mayumba
# Processing Record 47 of Set 9 | abu kamal
# Processing Record 48 of Set 9 | avera
# Processing Record 49 of Set 9 | general pico
# Processing Record 50 of Set 9 | kokopo
# Processing Record 1 of Set 10 | bousso
# Processing Record 2 of Set 10 | naron
# Processing Record 3 of Set 10 | the pas
# Processing Record 4 of Set 10 | spitsevka
# Processing Record 5 of Set 10 | beruwala
# Processing Record 6 of Set 10 | tuatapere
# Processing Record 7 of Set 10 | red bank
# Processing Record 8 of Set 10 | nara
# Processing Record 9 of Set 10 | kindia
# Processing Record 10 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 11 of Set 10 | dudinka
# Processing Record 12 of Set 10 | huambo
# Processing Record 13 of Set 10 | samana
# Processing Record 14 of Set 10 | darlawn
# Processing Record 15 of Set 10 | loa janan
# Processing Record 16 of Set 10 | krasnousolskiy
# City not found. Skipping...
# Processing Record 17 of Set 10 | peterhead
# Processing Record 18 of Set 10 | petatlan
# Processing Record 19 of Set 10 | lagunas
# Processing Record 20 of Set 10 | ishinomaki
# Processing Record 21 of Set 10 | kitami
# Processing Record 22 of Set 10 | fortuna
# Processing Record 23 of Set 10 | xaltianguis
# Processing Record 24 of Set 10 | port keats
# Processing Record 25 of Set 10 | taman
# Processing Record 26 of Set 10 | vydrino
# Processing Record 27 of Set 10 | rock sound
# Processing Record 28 of Set 10 | rio gallegos
# Processing Record 29 of Set 10 | merauke
# Processing Record 30 of Set 10 | sept-iles
# Processing Record 31 of Set 10 | shache
# Processing Record 32 of Set 10 | sangar
# Processing Record 33 of Set 10 | enterprise
# Processing Record 34 of Set 10 | mango
# Processing Record 35 of Set 10 | kutum
# Processing Record 36 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 10 | lai
# Processing Record 38 of Set 10 | kirzhach
# Processing Record 39 of Set 10 | san rafael
# Processing Record 40 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 10 | kieta
# Processing Record 42 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | nelson bay
# Processing Record 44 of Set 10 | kashi
# Processing Record 45 of Set 10 | portel
# Processing Record 46 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 10 | majene
# Processing Record 48 of Set 10 | maymyo
# Processing Record 49 of Set 10 | meridian
# Processing Record 50 of Set 10 | upata
# Processing Record 1 of Set 11 | tessalit
# Processing Record 2 of Set 11 | sioux city
# Processing Record 3 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 11 | penzance
# Processing Record 6 of Set 11 | killybegs
# Processing Record 7 of Set 11 | lodja
# Processing Record 8 of Set 11 | nynashamn
# Processing Record 9 of Set 11 | denau
# City not found. Skipping...
# Processing Record 10 of Set 11 | bubaque
# Processing Record 11 of Set 11 | nylstroom
# City not found. Skipping...
# Processing Record 12 of Set 11 | thanh hoa
# Processing Record 13 of Set 11 | rosario do sul
# Processing Record 14 of Set 11 | pacific grove
# Processing Record 15 of Set 11 | mbini
# Processing Record 16 of Set 11 | berberati
# Processing Record 17 of Set 11 | dano
# Processing Record 18 of Set 11 | khani
# Processing Record 19 of Set 11 | bara
# Processing Record 20 of Set 11 | raton
# Processing Record 21 of Set 11 | guangyuan
# Processing Record 22 of Set 11 | vangaindrano
# Processing Record 23 of Set 11 | te anau
# Processing Record 24 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 11 | thinadhoo
# Processing Record 27 of Set 11 | enumclaw
# Processing Record 28 of Set 11 | singaparna
# Processing Record 29 of Set 11 | hidalgo
# Processing Record 30 of Set 11 | grand forks
# Processing Record 31 of Set 11 | honiara
# Processing Record 32 of Set 11 | praia da vitoria
# Processing Record 33 of Set 11 | saint-denis
# Processing Record 34 of Set 11 | mangai
# Processing Record 35 of Set 11 | ndiekro
# City not found. Skipping...
# Processing Record 36 of Set 11 | lhokseumawe
# Processing Record 37 of Set 11 | roma
# Processing Record 38 of Set 11 | beringovskiy
# Processing Record 39 of Set 11 | havelock
# Processing Record 40 of Set 11 | acajutla
# Processing Record 41 of Set 11 | puerto quijarro
# Processing Record 42 of Set 11 | kargasok
# Processing Record 43 of Set 11 | freeport
# Processing Record 44 of Set 11 | bennettsville
# Processing Record 45 of Set 11 | dyurtyuli
# Processing Record 46 of Set 11 | emerald
# Processing Record 47 of Set 11 | ivanovka
# Processing Record 48 of Set 11 | sao sebastiao
# Processing Record 49 of Set 11 | mbinga
# Processing Record 50 of Set 11 | viksoyri
# City not found. Skipping...
# Processing Record 1 of Set 12 | amberley
# Processing Record 2 of Set 12 | gamba
# Processing Record 3 of Set 12 | jawhar
# Processing Record 4 of Set 12 | luban
# Processing Record 5 of Set 12 | farah
# Processing Record 6 of Set 12 | sorong
# Processing Record 7 of Set 12 | teguldet
# Processing Record 8 of Set 12 | kavaratti
# Processing Record 9 of Set 12 | mwense
# Processing Record 10 of Set 12 | ephrata
# Processing Record 11 of Set 12 | turayf
# Processing Record 12 of Set 12 | tucuman
# Processing Record 13 of Set 12 | westonaria
# Processing Record 14 of Set 12 | ambunti
# Processing Record 15 of Set 12 | mokhsogollokh
# Processing Record 16 of Set 12 | saravan
# Processing Record 17 of Set 12 | kununurra
# Processing Record 18 of Set 12 | el alto
# Processing Record 19 of Set 12 | itoman
# Processing Record 20 of Set 12 | effingham
# Processing Record 21 of Set 12 | ivanjica
# Processing Record 22 of Set 12 | qui nhon
# Processing Record 23 of Set 12 | campina verde
# Processing Record 24 of Set 12 | ordu
# Processing Record 25 of Set 12 | puente de ixtla
# Processing Record 26 of Set 12 | umm lajj
# Processing Record 27 of Set 12 | zelenogradsk
# Processing Record 28 of Set 12 | casper
# Processing Record 29 of Set 12 | zhicheng
# Processing Record 30 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 12 | karratha
# Processing Record 33 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 12 | bratsk
# Processing Record 35 of Set 12 | hoquiam
# Processing Record 36 of Set 12 | aden
# Processing Record 37 of Set 12 | kuanshan
# City not found. Skipping...
# Processing Record 38 of Set 12 | bowling green
# Processing Record 39 of Set 12 | autun
# Processing Record 40 of Set 12 | chapais
# Processing Record 41 of Set 12 | pisco
# Processing Record 42 of Set 12 | carahue
# Processing Record 43 of Set 12 | fray bentos
# Processing Record 44 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 45 of Set 12 | garowe
# Processing Record 46 of Set 12 | sacramento
# Processing Record 47 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 48 of Set 12 | panaba
# Processing Record 49 of Set 12 | port blair
# Processing Record 50 of Set 12 | sao filipe
# Processing Record 1 of Set 13 | palatka
# Processing Record 2 of Set 13 | aljezur
# Processing Record 3 of Set 13 | waipawa
# Processing Record 4 of Set 13 | severomuysk
# Processing Record 5 of Set 13 | mezen
# Processing Record 6 of Set 13 | safranbolu
# Processing Record 7 of Set 13 | ankang
# Processing Record 8 of Set 13 | evensk
# Processing Record 9 of Set 13 | lata
# Processing Record 10 of Set 13 | krasnozerskoye
# Processing Record 11 of Set 13 | togur
# Processing Record 12 of Set 13 | yakeshi
# Processing Record 13 of Set 13 | jian
# Processing Record 14 of Set 13 | clemencia
# Processing Record 15 of Set 13 | dong xoai
# Processing Record 16 of Set 13 | namatanai
# Processing Record 17 of Set 13 | hokitika
# Processing Record 18 of Set 13 | sakmara
# Processing Record 19 of Set 13 | ponta delgada
# Processing Record 20 of Set 13 | togul
# Processing Record 21 of Set 13 | kailua
# Processing Record 22 of Set 13 | indi
# Processing Record 23 of Set 13 | corinto
# Processing Record 24 of Set 13 | kadaya
# Processing Record 25 of Set 13 | potiskum
# Processing Record 26 of Set 13 | calvinia
# Processing Record 27 of Set 13 | goderich
# Processing Record 28 of Set 13 | casino
# Processing Record 29 of Set 13 | laguna
# Processing Record 30 of Set 13 | frontera
# Processing Record 31 of Set 13 | broken hill
# Processing Record 32 of Set 13 | nizhniy tsasuchey
# Processing Record 33 of Set 13 | slawno
# Processing Record 34 of Set 13 | bagdarin
# Processing Record 35 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 36 of Set 13 | san andres
# Processing Record 37 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 13 | lobito
# Processing Record 39 of Set 13 | cartagena
# Processing Record 40 of Set 13 | timbiras
# Processing Record 41 of Set 13 | huilong
# Processing Record 42 of Set 13 | lumut
# Processing Record 43 of Set 13 | krasnoselkup
# Processing Record 44 of Set 13 | basoko
# Processing Record 45 of Set 13 | bhanpuri
# Processing Record 46 of Set 13 | manaus
# Processing Record 47 of Set 13 | ermoupolis
# Processing Record 48 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 13 | vardo
# Processing Record 50 of Set 13 | moose factory
# Processing Record 1 of Set 14 | elat
# Processing Record 2 of Set 14 | bonavista
# Processing Record 3 of Set 14 | torbay
# Processing Record 4 of Set 14 | dingle
# Processing Record 5 of Set 14 | kuruman
# Processing Record 6 of Set 14 | najran
# Processing Record 7 of Set 14 | olinda
# Processing Record 8 of Set 14 | limbe
# Processing Record 9 of Set 14 | husavik
# Processing Record 10 of Set 14 | chimbote
# Processing Record 11 of Set 14 | cumbitara
# Processing Record 12 of Set 14 | banyo
# Processing Record 13 of Set 14 | valparaiso
# Processing Record 14 of Set 14 | ndele
# Processing Record 15 of Set 14 | cap malheureux
# Processing Record 16 of Set 14 | scarborough
# Processing Record 17 of Set 14 | aykhal
# Processing Record 18 of Set 14 | caucaia
# Processing Record 19 of Set 14 | gravdal
# Processing Record 20 of Set 14 | kristinehamn
# Processing Record 21 of Set 14 | sao miguel do araguaia
# Processing Record 22 of Set 14 | adrar
# Processing Record 23 of Set 14 | crotone
# Processing Record 24 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 14 | dovers
# Processing Record 26 of Set 14 | maniitsoq
# Processing Record 27 of Set 14 | freetown
# Processing Record 28 of Set 14 | williams lake
# Processing Record 29 of Set 14 | saint anthony
# Processing Record 30 of Set 14 | sur
# Processing Record 31 of Set 14 | reitz
# Processing Record 32 of Set 14 | san vicente
# Processing Record 33 of Set 14 | prince rupert
# Processing Record 34 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 14 | tautira
# Processing Record 36 of Set 14 | atka
# City not found. Skipping...
# Processing Record 37 of Set 14 | sterlibashevo
# Processing Record 38 of Set 14 | shingu
# Processing Record 39 of Set 14 | sao jose da coroa grande
# Processing Record 40 of Set 14 | noyabrsk
# Processing Record 41 of Set 14 | antalaha
# Processing Record 42 of Set 14 | galyugayevskaya
# Processing Record 43 of Set 14 | palang
# Processing Record 44 of Set 14 | charters towers
# Processing Record 45 of Set 14 | shirokiy
# Processing Record 46 of Set 14 | sherbakul
# Processing Record 47 of Set 14 | long xuyen
# Processing Record 48 of Set 14 | timmins
# Processing Record 49 of Set 14 | loreto
# Processing Record 50 of Set 14 | ulaanbaatar
# Processing Record 1 of Set 15 | skibbereen
# Processing Record 2 of Set 15 | kupang
# Processing Record 3 of Set 15 | ouesso
# Processing Record 4 of Set 15 | vila do maio
# Processing Record 5 of Set 15 | yashalta
# Processing Record 6 of Set 15 | williston
# Processing Record 7 of Set 15 | kangaatsiaq
# Processing Record 8 of Set 15 | kruisfontein
# Processing Record 9 of Set 15 | magan
# Processing Record 10 of Set 15 | gotsu
# Processing Record 11 of Set 15 | auray
# Processing Record 12 of Set 15 | anori
# Processing Record 13 of Set 15 | richards bay
# Processing Record 14 of Set 15 | savelugu
# Processing Record 15 of Set 15 | casablanca
# Processing Record 16 of Set 15 | yamethin
# Processing Record 17 of Set 15 | ciudad real
# Processing Record 18 of Set 15 | springbok
# Processing Record 19 of Set 15 | caranavi
# Processing Record 20 of Set 15 | north bend
# Processing Record 21 of Set 15 | pontes e lacerda
# Processing Record 22 of Set 15 | gaziantep
# Processing Record 23 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 24 of Set 15 | san ramon
# Processing Record 25 of Set 15 | areka
# Processing Record 26 of Set 15 | carupano
# Processing Record 27 of Set 15 | tupik
# Processing Record 28 of Set 15 | tambacounda
# Processing Record 29 of Set 15 | arvika
# Processing Record 30 of Set 15 | yar-sale
# Processing Record 31 of Set 15 | itarema
# Processing Record 32 of Set 15 | lgov
# Processing Record 33 of Set 15 | florianopolis
# Processing Record 34 of Set 15 | san martin
# Processing Record 35 of Set 15 | chifeng
# Processing Record 36 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 37 of Set 15 | nuuk
# Processing Record 38 of Set 15 | cayenne
# Processing Record 39 of Set 15 | ann arbor
# Processing Record 40 of Set 15 | dali
# Processing Record 41 of Set 15 | baracoa
# Processing Record 42 of Set 15 | petropavlovka
# Processing Record 43 of Set 15 | weihe
# Processing Record 44 of Set 15 | smithers
# Processing Record 45 of Set 15 | warora
# Processing Record 46 of Set 15 | warud
# Processing Record 47 of Set 15 | odienne
# Processing Record 48 of Set 15 | santa isabel do rio negro
# Processing Record 49 of Set 15 | jiuquan
# Processing Record 50 of Set 15 | boshnyakovo
# Processing Record 1 of Set 16 | bontang
# Processing Record 2 of Set 16 | kasane
# Processing Record 3 of Set 16 | hornepayne
# Processing Record 4 of Set 16 | soe
# Processing Record 5 of Set 16 | verdalsora
# City not found. Skipping...
# Processing Record 6 of Set 16 | angoche
# Processing Record 7 of Set 16 | ulundi
# Processing Record 8 of Set 16 | pangnirtung
# Processing Record 9 of Set 16 | sainte-rose
# Processing Record 10 of Set 16 | caledon
# Processing Record 11 of Set 16 | klamath falls
# Processing Record 12 of Set 16 | seddon
# Processing Record 13 of Set 16 | severo-yeniseyskiy
# Processing Record 14 of Set 16 | point fortin
# Processing Record 15 of Set 16 | akdepe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Quatre Cocos -20.2078   57.7625     84.09        75           5
# 1      Lorengau  -2.0226  147.2712     82.51        75          99
# 2      Kineshma  57.4391   42.1289     13.37        96         100
# 3    Bredasdorp -34.5322   20.0403     62.28        88          43
# 4     Martapura  -3.4167  114.8500     86.09        66          20
#
#    Wind Speed Country                 Date           Weather
# 0       10.65      MU  2022-01-29 04:50:20         clear sky
# 1        3.87      PG  2022-01-29 04:50:20   overcast clouds
# 2        6.49      RU  2022-01-29 04:50:20              snow
# 3        5.75      ZA  2022-01-29 04:50:21  scattered clouds
# 4        8.05      ID  2022-01-29 04:50:21        few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Weather"]

new_city_data_df = city_data_df[new_column_order]

new_city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Quatre Cocos      MU -20.2078   57.7625     84.09        75
# 1              Lorengau      PG  -2.0226  147.2712     82.51        75
# 2              Kineshma      RU  57.4391   42.1289     13.37        96
# 3            Bredasdorp      ZA -34.5322   20.0403     62.28        88
# 4             Martapura      ID  -3.4167  114.8500     86.09        66
# ..                  ...     ...      ...       ...       ...       ...
# 693       Klamath Falls      US  42.2249 -121.7817     35.87        55
# 694              Seddon      AU -37.8068  144.8916     74.61        75
# 695  Severo-Yeniseyskiy      RU  60.3725   93.0408      4.69        92
# 696        Point Fortin      TT  10.1833  -61.6833     71.85        77
# 697              Akdepe      TM  42.0551   59.3788     23.00        71
#
#      Cloudiness  Wind Speed           Weather
# 0             5       10.65         clear sky
# 1            99        3.87   overcast clouds
# 2           100        6.49              snow
# 3            43        5.75  scattered clouds
# 4            20        8.05        few clouds
# ..          ...         ...               ...
# 693          84        1.01     broken clouds
# 694         100        7.00   overcast clouds
# 695          99        6.49        light snow
# 696           1        8.97         clear sky
# 697           6        8.50         clear sky
#
# [698 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
