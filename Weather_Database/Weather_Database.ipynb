# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | banda aceh
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | ambalavao
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | pangnirtung
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | mweka
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | cooma
# Processing Record 25 of Set 1 | ahipara
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | haverfordwest
# Processing Record 28 of Set 1 | coihaique
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | colomi
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | broome
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | srednekolymsk
# Processing Record 36 of Set 1 | monrovia
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | diamantino
# Processing Record 39 of Set 1 | meadow lake
# Processing Record 40 of Set 1 | navalmoral de la mata
# Processing Record 41 of Set 1 | pokosnoye
# Processing Record 42 of Set 1 | dharchula
# Processing Record 43 of Set 1 | odweyne
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | nador
# Processing Record 46 of Set 1 | minab
# Processing Record 47 of Set 1 | sayat
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | fairbanks
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | ponta delgada
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | ankazoabo
# Processing Record 8 of Set 2 | yenagoa
# Processing Record 9 of Set 2 | cherskiy
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | bathsheba
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | panaba
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | krasnyy chikoy
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | raudeberg
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | galesong
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | chokwe
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | luanda
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | itaituba
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | kargil
# Processing Record 37 of Set 2 | vila do maio
# Processing Record 38 of Set 2 | hohhot
# Processing Record 39 of Set 2 | mareeba
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | sawakin
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | cairns
# Processing Record 46 of Set 2 | mahibadhoo
# Processing Record 47 of Set 2 | ilulissat
# Processing Record 48 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 2 | chokurdakh
# Processing Record 50 of Set 2 | whitehorse
# Processing Record 1 of Set 3 | semporna
# Processing Record 2 of Set 3 | cirie
# Processing Record 3 of Set 3 | marinette
# Processing Record 4 of Set 3 | sorong
# Processing Record 5 of Set 3 | oranjemund
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | sayyan
# Processing Record 9 of Set 3 | matara
# Processing Record 10 of Set 3 | taclobo
# Processing Record 11 of Set 3 | hamilton
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | itaguai
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | sampit
# Processing Record 16 of Set 3 | nadym
# Processing Record 17 of Set 3 | nome
# Processing Record 18 of Set 3 | chaupimarca
# Processing Record 19 of Set 3 | san cristobal
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 3 | salalah
# Processing Record 23 of Set 3 | kavieng
# Processing Record 24 of Set 3 | zabol
# Processing Record 25 of Set 3 | tual
# Processing Record 26 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 3 | faanui
# Processing Record 28 of Set 3 | chicama
# Processing Record 29 of Set 3 | port hardy
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | mineiros
# Processing Record 32 of Set 3 | lucapa
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | benguela
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | killybegs
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | manaus
# Processing Record 41 of Set 3 | donskoye
# Processing Record 42 of Set 3 | miyang
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | irituia
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | tsiroanomandidy
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | tabuk
# Processing Record 49 of Set 3 | ivanivka
# Processing Record 50 of Set 3 | dunedin
# Processing Record 1 of Set 4 | verkhoyansk
# Processing Record 2 of Set 4 | olafsvik
# Processing Record 3 of Set 4 | korla
# Processing Record 4 of Set 4 | harrai
# Processing Record 5 of Set 4 | vanimo
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | dhari
# Processing Record 9 of Set 4 | alibag
# Processing Record 10 of Set 4 | mnogovershinnyy
# Processing Record 11 of Set 4 | thinadhoo
# Processing Record 12 of Set 4 | novokruchininskiy
# Processing Record 13 of Set 4 | naze
# Processing Record 14 of Set 4 | lufilufi
# Processing Record 15 of Set 4 | yerazgavors
# Processing Record 16 of Set 4 | sinj
# Processing Record 17 of Set 4 | kambove
# Processing Record 18 of Set 4 | aripuana
# Processing Record 19 of Set 4 | merauke
# Processing Record 20 of Set 4 | nongstoin
# Processing Record 21 of Set 4 | bam
# Processing Record 22 of Set 4 | dabakala
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | serenje
# Processing Record 25 of Set 4 | coquimbo
# Processing Record 26 of Set 4 | luhyny
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | ubud
# Processing Record 31 of Set 4 | nabire
# Processing Record 32 of Set 4 | nanortalik
# Processing Record 33 of Set 4 | stokmarknes
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | tuktoyaktuk
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | camopi
# Processing Record 40 of Set 4 | san jose
# Processing Record 41 of Set 4 | deputatskiy
# Processing Record 42 of Set 4 | port moresby
# Processing Record 43 of Set 4 | makubetsu
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | tonantins
# Processing Record 46 of Set 4 | ambilobe
# Processing Record 47 of Set 4 | aswan
# Processing Record 48 of Set 4 | yumen
# Processing Record 49 of Set 4 | taltal
# Processing Record 50 of Set 4 | najran
# Processing Record 1 of Set 5 | cardston
# Processing Record 2 of Set 5 | paraiso
# Processing Record 3 of Set 5 | emba
# Processing Record 4 of Set 5 | tondano
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | san marcos
# Processing Record 7 of Set 5 | klaksvik
# Processing Record 8 of Set 5 | huarmey
# Processing Record 9 of Set 5 | beloye
# Processing Record 10 of Set 5 | waipawa
# Processing Record 11 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | ngudu
# Processing Record 14 of Set 5 | palmer
# Processing Record 15 of Set 5 | kungurtug
# Processing Record 16 of Set 5 | machali
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | barcelos
# Processing Record 19 of Set 5 | tynset
# Processing Record 20 of Set 5 | ziro
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | clyde
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | wasilla
# Processing Record 25 of Set 5 | bandarbeyla
# Processing Record 26 of Set 5 | asosa
# Processing Record 27 of Set 5 | ostrovnoy
# Processing Record 28 of Set 5 | sistranda
# Processing Record 29 of Set 5 | igarka
# Processing Record 30 of Set 5 | leh
# Processing Record 31 of Set 5 | ravar
# Processing Record 32 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 5 | carnarvon
# Processing Record 34 of Set 5 | barra do garcas
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | kasongo-lunda
# Processing Record 37 of Set 5 | tshela
# Processing Record 38 of Set 5 | saint-augustin
# Processing Record 39 of Set 5 | sawtell
# Processing Record 40 of Set 5 | mount gambier
# Processing Record 41 of Set 5 | bratsk
# Processing Record 42 of Set 5 | hailar
# Processing Record 43 of Set 5 | manokwari
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | puerto escondido
# Processing Record 46 of Set 5 | paamiut
# Processing Record 47 of Set 5 | kulim
# Processing Record 48 of Set 5 | leningradskiy
# Processing Record 49 of Set 5 | torbay
# Processing Record 50 of Set 5 | almaznyy
# Processing Record 1 of Set 6 | calvinia
# Processing Record 2 of Set 6 | heihe
# Processing Record 3 of Set 6 | port elizabeth
# Processing Record 4 of Set 6 | hasaki
# Processing Record 5 of Set 6 | asau
# Processing Record 6 of Set 6 | sinnamary
# Processing Record 7 of Set 6 | kenai
# Processing Record 8 of Set 6 | labuhan
# Processing Record 9 of Set 6 | trincomalee
# Processing Record 10 of Set 6 | mao
# Processing Record 11 of Set 6 | price
# Processing Record 12 of Set 6 | rawson
# Processing Record 13 of Set 6 | carauari
# Processing Record 14 of Set 6 | nadvoitsy
# Processing Record 15 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 6 | hami
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | nerchinsk
# Processing Record 19 of Set 6 | verdalsora
# City not found. Skipping...
# Processing Record 20 of Set 6 | makakilo city
# Processing Record 21 of Set 6 | ancud
# Processing Record 22 of Set 6 | ponta do sol
# Processing Record 23 of Set 6 | vila franca do campo
# Processing Record 24 of Set 6 | santa rosa
# Processing Record 25 of Set 6 | north bend
# Processing Record 26 of Set 6 | otradnoye
# Processing Record 27 of Set 6 | san policarpo
# Processing Record 28 of Set 6 | west helena
# Processing Record 29 of Set 6 | santarem
# Processing Record 30 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 6 | port-cartier
# Processing Record 32 of Set 6 | takaka
# Processing Record 33 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 6 | araouane
# Processing Record 35 of Set 6 | charyshskoye
# Processing Record 36 of Set 6 | itarema
# Processing Record 37 of Set 6 | maneadero
# Processing Record 38 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 6 | nelson bay
# Processing Record 40 of Set 6 | am timan
# Processing Record 41 of Set 6 | porto walter
# Processing Record 42 of Set 6 | piacabucu
# Processing Record 43 of Set 6 | bani walid
# Processing Record 44 of Set 6 | kuytun
# Processing Record 45 of Set 6 | newport
# Processing Record 46 of Set 6 | acapulco
# Processing Record 47 of Set 6 | balotra
# Processing Record 48 of Set 6 | campuyo
# City not found. Skipping...
# Processing Record 49 of Set 6 | nishihara
# Processing Record 50 of Set 6 | moose factory
# Processing Record 1 of Set 7 | floresta
# Processing Record 2 of Set 7 | blackwater
# Processing Record 3 of Set 7 | kyren
# Processing Record 4 of Set 7 | koumac
# Processing Record 5 of Set 7 | benjamin hill
# Processing Record 6 of Set 7 | chuy
# Processing Record 7 of Set 7 | jamame
# Processing Record 8 of Set 7 | arraial do cabo
# Processing Record 9 of Set 7 | malanje
# Processing Record 10 of Set 7 | kaifeng
# Processing Record 11 of Set 7 | zahirabad
# Processing Record 12 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 7 | lagos
# Processing Record 14 of Set 7 | bonfim
# Processing Record 15 of Set 7 | lerwick
# Processing Record 16 of Set 7 | garden city
# Processing Record 17 of Set 7 | norman wells
# Processing Record 18 of Set 7 | indore
# Processing Record 19 of Set 7 | mustafakemalpasa
# Processing Record 20 of Set 7 | desbiens
# Processing Record 21 of Set 7 | yerbogachen
# Processing Record 22 of Set 7 | bandar-e lengeh
# Processing Record 23 of Set 7 | lebork
# Processing Record 24 of Set 7 | taksimo
# Processing Record 25 of Set 7 | qarayeri
# Processing Record 26 of Set 7 | toora-khem
# Processing Record 27 of Set 7 | atar
# Processing Record 28 of Set 7 | glenluce
# Processing Record 29 of Set 7 | cabedelo
# Processing Record 30 of Set 7 | pacific grove
# Processing Record 31 of Set 7 | rio grande
# Processing Record 32 of Set 7 | mackenzie
# Processing Record 33 of Set 7 | pangkah
# Processing Record 34 of Set 7 | komsomolskiy
# Processing Record 35 of Set 7 | souillac
# Processing Record 36 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 7 | aykhal
# Processing Record 38 of Set 7 | juba
# Processing Record 39 of Set 7 | buala
# Processing Record 40 of Set 7 | talaya
# Processing Record 41 of Set 7 | yulara
# Processing Record 42 of Set 7 | shentala
# Processing Record 43 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 7 | visby
# Processing Record 45 of Set 7 | joensuu
# Processing Record 46 of Set 7 | awbari
# Processing Record 47 of Set 7 | kununurra
# Processing Record 48 of Set 7 | lappeenranta
# Processing Record 49 of Set 7 | ust-kuyga
# Processing Record 50 of Set 7 | norway
# Processing Record 1 of Set 8 | mount pleasant
# Processing Record 2 of Set 8 | namibe
# Processing Record 3 of Set 8 | taoudenni
# Processing Record 4 of Set 8 | bilma
# Processing Record 5 of Set 8 | berdigestyakh
# Processing Record 6 of Set 8 | aklavik
# Processing Record 7 of Set 8 | magadan
# Processing Record 8 of Set 8 | orange cove
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | kalmunai
# Processing Record 11 of Set 8 | qaqortoq
# Processing Record 12 of Set 8 | lazaro cardenas
# Processing Record 13 of Set 8 | port hedland
# Processing Record 14 of Set 8 | along
# Processing Record 15 of Set 8 | rosarito
# Processing Record 16 of Set 8 | lloydminster
# Processing Record 17 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 8 | atka
# City not found. Skipping...
# Processing Record 19 of Set 8 | nemuro
# Processing Record 20 of Set 8 | vestmanna
# Processing Record 21 of Set 8 | boa vista
# Processing Record 22 of Set 8 | bridgetown
# Processing Record 23 of Set 8 | harper
# Processing Record 24 of Set 8 | pervomayskiy
# Processing Record 25 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 26 of Set 8 | constitucion
# Processing Record 27 of Set 8 | la asuncion
# Processing Record 28 of Set 8 | husavik
# Processing Record 29 of Set 8 | chumikan
# Processing Record 30 of Set 8 | kavaratti
# Processing Record 31 of Set 8 | brae
# Processing Record 32 of Set 8 | ambulu
# Processing Record 33 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 8 | san juan
# Processing Record 35 of Set 8 | lahan
# Processing Record 36 of Set 8 | hay river
# Processing Record 37 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 8 | sinjai
# Processing Record 39 of Set 8 | fort nelson
# Processing Record 40 of Set 8 | sisimiut
# Processing Record 41 of Set 8 | umm kaddadah
# Processing Record 42 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 8 | ormara
# Processing Record 44 of Set 8 | margate
# Processing Record 45 of Set 8 | port shepstone
# Processing Record 46 of Set 8 | balabac
# Processing Record 47 of Set 8 | inuvik
# Processing Record 48 of Set 8 | isangel
# Processing Record 49 of Set 8 | mahabad
# Processing Record 50 of Set 8 | mogadishu
# Processing Record 1 of Set 9 | channel-port aux basques
# Processing Record 2 of Set 9 | batagay-alyta
# Processing Record 3 of Set 9 | weligama
# Processing Record 4 of Set 9 | westport
# Processing Record 5 of Set 9 | rocha
# Processing Record 6 of Set 9 | ulladulla
# Processing Record 7 of Set 9 | arukula
# Processing Record 8 of Set 9 | santa cruz
# Processing Record 9 of Set 9 | tura
# Processing Record 10 of Set 9 | bokoro
# Processing Record 11 of Set 9 | pingliang
# Processing Record 12 of Set 9 | ahraura
# Processing Record 13 of Set 9 | tabas
# Processing Record 14 of Set 9 | vaasa
# Processing Record 15 of Set 9 | alanya
# Processing Record 16 of Set 9 | bairiki
# Processing Record 17 of Set 9 | zhangjiakou
# Processing Record 18 of Set 9 | saryg-sep
# Processing Record 19 of Set 9 | maningrida
# Processing Record 20 of Set 9 | basco
# Processing Record 21 of Set 9 | cayenne
# Processing Record 22 of Set 9 | vostok
# Processing Record 23 of Set 9 | pedernales
# Processing Record 24 of Set 9 | temir
# Processing Record 25 of Set 9 | bulawayo
# Processing Record 26 of Set 9 | bluefields
# Processing Record 27 of Set 9 | bud
# Processing Record 28 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 29 of Set 9 | dodge city
# Processing Record 30 of Set 9 | bonthe
# Processing Record 31 of Set 9 | serebryansk
# Processing Record 32 of Set 9 | pimentel
# Processing Record 33 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 34 of Set 9 | cochrane
# Processing Record 35 of Set 9 | zakamensk
# Processing Record 36 of Set 9 | abu dhabi
# Processing Record 37 of Set 9 | acari
# Processing Record 38 of Set 9 | orlik
# Processing Record 39 of Set 9 | atherton
# Processing Record 40 of Set 9 | jilmah
# City not found. Skipping...
# Processing Record 41 of Set 9 | flin flon
# Processing Record 42 of Set 9 | tezu
# Processing Record 43 of Set 9 | kanker
# Processing Record 44 of Set 9 | saint-pierre
# Processing Record 45 of Set 9 | ozamiz
# Processing Record 46 of Set 9 | karlstad
# Processing Record 47 of Set 9 | maldonado
# Processing Record 48 of Set 9 | fethiye
# Processing Record 49 of Set 9 | biloela
# Processing Record 50 of Set 9 | erzin
# Processing Record 1 of Set 10 | kupang
# Processing Record 2 of Set 10 | los llanos de aridane
# Processing Record 3 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 10 | ridgecrest
# Processing Record 5 of Set 10 | egvekinot
# Processing Record 6 of Set 10 | shemonaikha
# Processing Record 7 of Set 10 | beira
# Processing Record 8 of Set 10 | ust-tsilma
# Processing Record 9 of Set 10 | mabama
# Processing Record 10 of Set 10 | sharjah
# Processing Record 11 of Set 10 | alice springs
# Processing Record 12 of Set 10 | kiunga
# Processing Record 13 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 10 | puerto colombia
# Processing Record 15 of Set 10 | cap malheureux
# Processing Record 16 of Set 10 | codrington
# Processing Record 17 of Set 10 | zarand
# Processing Record 18 of Set 10 | haines junction
# Processing Record 19 of Set 10 | boysun
# Processing Record 20 of Set 10 | pijijiapan
# Processing Record 21 of Set 10 | hammerfest
# Processing Record 22 of Set 10 | gra liyia
# Processing Record 23 of Set 10 | moron
# Processing Record 24 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 10 | karratha
# Processing Record 26 of Set 10 | tabou
# Processing Record 27 of Set 10 | port lincoln
# Processing Record 28 of Set 10 | portland
# Processing Record 29 of Set 10 | kieta
# Processing Record 30 of Set 10 | mehamn
# Processing Record 31 of Set 10 | ulety
# Processing Record 32 of Set 10 | wanaka
# Processing Record 33 of Set 10 | sao joao da barra
# Processing Record 34 of Set 10 | jieshi
# Processing Record 35 of Set 10 | yanam
# Processing Record 36 of Set 10 | kapit
# Processing Record 37 of Set 10 | kalabo
# Processing Record 38 of Set 10 | nouakchott
# Processing Record 39 of Set 10 | mogok
# Processing Record 40 of Set 10 | goregaon
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | bambanglipuro
# Processing Record 43 of Set 10 | peniche
# Processing Record 44 of Set 10 | durham
# Processing Record 45 of Set 10 | maryville
# Processing Record 46 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | cumbum
# Processing Record 49 of Set 10 | sorland
# Processing Record 50 of Set 10 | north platte
# Processing Record 1 of Set 11 | kushmurun
# Processing Record 2 of Set 11 | novoagansk
# Processing Record 3 of Set 11 | nouadhibou
# Processing Record 4 of Set 11 | awjilah
# Processing Record 5 of Set 11 | lapao
# Processing Record 6 of Set 11 | zemio
# Processing Record 7 of Set 11 | bafq
# Processing Record 8 of Set 11 | monster
# Processing Record 9 of Set 11 | jeremie
# Processing Record 10 of Set 11 | lidkoping
# Processing Record 11 of Set 11 | dongsheng
# Processing Record 12 of Set 11 | benxi
# Processing Record 13 of Set 11 | samarai
# Processing Record 14 of Set 11 | saint-henri-de-levis
# City not found. Skipping...
# Processing Record 15 of Set 11 | galle
# Processing Record 16 of Set 11 | phan thiet
# Processing Record 17 of Set 11 | stornoway
# Processing Record 18 of Set 11 | batemans bay
# Processing Record 19 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 11 | teya
# Processing Record 21 of Set 11 | mufulira
# Processing Record 22 of Set 11 | mahenge
# Processing Record 23 of Set 11 | yichun
# Processing Record 24 of Set 11 | kidal
# Processing Record 25 of Set 11 | strezhevoy
# Processing Record 26 of Set 11 | temba
# Processing Record 27 of Set 11 | galveston
# Processing Record 28 of Set 11 | lompoc
# Processing Record 29 of Set 11 | ambon
# Processing Record 30 of Set 11 | shingu
# Processing Record 31 of Set 11 | alberton
# Processing Record 32 of Set 11 | tiquisio
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | poum
# Processing Record 35 of Set 11 | chhabra
# Processing Record 36 of Set 11 | kvarkeno
# Processing Record 37 of Set 11 | dalvik
# Processing Record 38 of Set 11 | mayskiy
# Processing Record 39 of Set 11 | syracuse
# Processing Record 40 of Set 11 | ambalema
# Processing Record 41 of Set 11 | orotukan
# Processing Record 42 of Set 11 | taybad
# Processing Record 43 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 11 | gravelbourg
# Processing Record 45 of Set 11 | toktogul
# Processing Record 46 of Set 11 | menongue
# Processing Record 47 of Set 11 | kahului
# Processing Record 48 of Set 11 | berlevag
# Processing Record 49 of Set 11 | kolokani
# Processing Record 50 of Set 11 | rio gallegos
# Processing Record 1 of Set 12 | yol
# Processing Record 2 of Set 12 | malakal
# Processing Record 3 of Set 12 | mizdah
# Processing Record 4 of Set 12 | neftcala
# Processing Record 5 of Set 12 | phonhong
# Processing Record 6 of Set 12 | beloha
# Processing Record 7 of Set 12 | namatanai
# Processing Record 8 of Set 12 | gari
# Processing Record 9 of Set 12 | bauchi
# Processing Record 10 of Set 12 | upata
# Processing Record 11 of Set 12 | katsuura
# Processing Record 12 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 12 | lasa
# Processing Record 14 of Set 12 | constantin daicoviciu
# Processing Record 15 of Set 12 | belmonte
# Processing Record 16 of Set 12 | natal
# Processing Record 17 of Set 12 | mahina
# Processing Record 18 of Set 12 | muros
# Processing Record 19 of Set 12 | pachino
# Processing Record 20 of Set 12 | sumenep
# Processing Record 21 of Set 12 | gjirokaster
# Processing Record 22 of Set 12 | sao gabriel da cachoeira
# Processing Record 23 of Set 12 | batticaloa
# Processing Record 24 of Set 12 | veseloyarsk
# Processing Record 25 of Set 12 | undory
# Processing Record 26 of Set 12 | jurm
# Processing Record 27 of Set 12 | marsa matruh
# Processing Record 28 of Set 12 | riberalta
# Processing Record 29 of Set 12 | russell
# Processing Record 30 of Set 12 | sovetskaya gavan
# Processing Record 31 of Set 12 | kashi
# Processing Record 32 of Set 12 | lodja
# Processing Record 33 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 12 | yagodnoye
# Processing Record 35 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 36 of Set 12 | tiarei
# Processing Record 37 of Set 12 | parfenyevo
# Processing Record 38 of Set 12 | kysyl-syr
# Processing Record 39 of Set 12 | chiredzi
# Processing Record 40 of Set 12 | talavera
# Processing Record 41 of Set 12 | fujin
# Processing Record 42 of Set 12 | velizh
# Processing Record 43 of Set 12 | iraquara
# Processing Record 44 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 12 | kargasok
# Processing Record 46 of Set 12 | mayo
# Processing Record 47 of Set 12 | tutoia
# Processing Record 48 of Set 12 | brownsville
# Processing Record 49 of Set 12 | marawi
# Processing Record 50 of Set 12 | kunda
# Processing Record 1 of Set 13 | novyy urengoy
# Processing Record 2 of Set 13 | muisne
# Processing Record 3 of Set 13 | yabassi
# Processing Record 4 of Set 13 | la ronge
# Processing Record 5 of Set 13 | ahuimanu
# Processing Record 6 of Set 13 | kurumkan
# Processing Record 7 of Set 13 | beyneu
# Processing Record 8 of Set 13 | clocolan
# Processing Record 9 of Set 13 | beni mazar
# Processing Record 10 of Set 13 | finschhafen
# Processing Record 11 of Set 13 | papetoai
# Processing Record 12 of Set 13 | tobe
# Processing Record 13 of Set 13 | likasi
# Processing Record 14 of Set 13 | farkhor
# Processing Record 15 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 13 | oytal
# Processing Record 17 of Set 13 | surt
# Processing Record 18 of Set 13 | ligayan
# Processing Record 19 of Set 13 | velykyy burluk
# Processing Record 20 of Set 13 | dauphin
# Processing Record 21 of Set 13 | ust-ordynskiy
# Processing Record 22 of Set 13 | axim
# Processing Record 23 of Set 13 | praia da vitoria
# Processing Record 24 of Set 13 | daimiel
# Processing Record 25 of Set 13 | taber
# Processing Record 26 of Set 13 | chelbasskaya
# Processing Record 27 of Set 13 | buraydah
# Processing Record 28 of Set 13 | saint george
# Processing Record 29 of Set 13 | avera
# Processing Record 30 of Set 13 | suntar
# Processing Record 31 of Set 13 | kawalu
# Processing Record 32 of Set 13 | manaquiri
# Processing Record 33 of Set 13 | vila
# Processing Record 34 of Set 13 | puerto ayacucho
# Processing Record 35 of Set 13 | morogoro
# Processing Record 36 of Set 13 | lagoa
# Processing Record 37 of Set 13 | avenal
# Processing Record 38 of Set 13 | loandjili
# Processing Record 39 of Set 13 | sola
# Processing Record 40 of Set 13 | ilukste
# Processing Record 41 of Set 13 | tromso
# Processing Record 42 of Set 13 | foam lake
# Processing Record 43 of Set 13 | lavrentiya
# Processing Record 44 of Set 13 | yomou
# Processing Record 45 of Set 13 | escuintla
# Processing Record 46 of Set 13 | jacareacanga
# Processing Record 47 of Set 13 | anori
# Processing Record 48 of Set 13 | chyhyryn
# Processing Record 49 of Set 13 | mackay
# Processing Record 50 of Set 13 | fasa
# Processing Record 1 of Set 14 | ternate
# Processing Record 2 of Set 14 | henties bay
# Processing Record 3 of Set 14 | port hawkesbury
# Processing Record 4 of Set 14 | bowen
# Processing Record 5 of Set 14 | lesnoy
# Processing Record 6 of Set 14 | leshan
# Processing Record 7 of Set 14 | gat
# Processing Record 8 of Set 14 | hillsborough
# Processing Record 9 of Set 14 | dalbandin
# Processing Record 10 of Set 14 | touba
# Processing Record 11 of Set 14 | aksu
# Processing Record 12 of Set 14 | silver city
# Processing Record 13 of Set 14 | kudahuvadhoo
# Processing Record 14 of Set 14 | punta alta
# Processing Record 15 of Set 14 | hambantota
# Processing Record 16 of Set 14 | kainantu
# Processing Record 17 of Set 14 | tyukhtet
# Processing Record 18 of Set 14 | labuan
# Processing Record 19 of Set 14 | salinopolis
# Processing Record 20 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 21 of Set 14 | talcahuano
# Processing Record 22 of Set 14 | erdenet
# Processing Record 23 of Set 14 | kirchlinteln
# Processing Record 24 of Set 14 | aktash
# Processing Record 25 of Set 14 | vestmannaeyjar
# Processing Record 26 of Set 14 | saint-joseph
# Processing Record 27 of Set 14 | soyo
# Processing Record 28 of Set 14 | tevriz
# Processing Record 29 of Set 14 | matias barbosa
# Processing Record 30 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 14 | lethem
# Processing Record 32 of Set 14 | urusha
# Processing Record 33 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 14 | santa cruz cabralia
# Processing Record 35 of Set 14 | omboue
# Processing Record 36 of Set 14 | agadez
# Processing Record 37 of Set 14 | yuli
# Processing Record 38 of Set 14 | jackson
# Processing Record 39 of Set 14 | saint pete beach
# Processing Record 40 of Set 14 | wajir
# Processing Record 41 of Set 14 | windhoek
# Processing Record 42 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | vila velha
# Processing Record 44 of Set 14 | zhezkazgan
# Processing Record 45 of Set 14 | cabras
# Processing Record 46 of Set 14 | dejen
# Processing Record 47 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 14 | zhuhai
# Processing Record 49 of Set 14 | armidale
# Processing Record 50 of Set 14 | umm lajj
# Processing Record 1 of Set 15 | promissao
# Processing Record 2 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 15 | lampazos de naranjo
# Processing Record 4 of Set 15 | kroya
# Processing Record 5 of Set 15 | tocopilla
# Processing Record 6 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 15 | camacha
# Processing Record 8 of Set 15 | asenovgrad
# Processing Record 9 of Set 15 | ucluelet
# Processing Record 10 of Set 15 | olga
# Processing Record 11 of Set 15 | faya
# Processing Record 12 of Set 15 | pitimbu
# Processing Record 13 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 14 of Set 15 | zhanaozen
# Processing Record 15 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 15 | tomatlan
# Processing Record 17 of Set 15 | grindavik
# Processing Record 18 of Set 15 | taquari
# Processing Record 19 of Set 15 | penzance
# Processing Record 20 of Set 15 | yelniki
# Processing Record 21 of Set 15 | gympie
# Processing Record 22 of Set 15 | evensk
# Processing Record 23 of Set 15 | baghmara
# Processing Record 24 of Set 15 | piombino
# Processing Record 25 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 15 | caravelas
# Processing Record 27 of Set 15 | wanning
# Processing Record 28 of Set 15 | olinda
# Processing Record 29 of Set 15 | chudniv
# Processing Record 30 of Set 15 | ouadda
# Processing Record 31 of Set 15 | havre-saint-pierre
# Processing Record 32 of Set 15 | mandalgovi
# Processing Record 33 of Set 15 | dicabisagan
# Processing Record 34 of Set 15 | tessalit
# Processing Record 35 of Set 15 | kloulklubed
# Processing Record 36 of Set 15 | totma
# Processing Record 37 of Set 15 | grand gaube
# Processing Record 38 of Set 15 | madang
# Processing Record 39 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 40 of Set 15 | lokomotivnyy
# Processing Record 41 of Set 15 | guarapari
# Processing Record 42 of Set 15 | manacapuru
# Processing Record 43 of Set 15 | dawson creek
# Processing Record 44 of Set 15 | sibolga
# Processing Record 45 of Set 15 | angoram
# Processing Record 46 of Set 15 | ialibu
# Processing Record 47 of Set 15 | aktau
# Processing Record 48 of Set 15 | misratah
# Processing Record 49 of Set 15 | show low
# Processing Record 50 of Set 15 | peace river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Hobart -42.8794  147.3294     73.27        70          75        1.99
# 1       Dikson  73.5069   80.5464      1.78        94         100       18.52
# 2   Butaritari   3.0707  172.7902     81.66        80          64       17.58
# 3        Tiksi  71.6872  128.8694    -10.16        99          32        6.49
# 4  East London -33.0153   27.9116     68.94        83           0        6.91
#
#   Country                 Date Current Description
# 0      AU  2022-01-29 05:22:59       broken clouds
# 1      RU  2022-01-29 05:19:13     overcast clouds
# 2      KI  2022-01-29 05:23:00       broken clouds
# 3      RU  2022-01-29 05:23:00    scattered clouds
# 4      ZA  2022-01-29 05:23:00           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]

new_city_data_df = city_data_df[new_column_order]

new_city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hobart      AU -42.8794  147.3294     73.27        70          75
# 1         Dikson      RU  73.5069   80.5464      1.78        94         100
# 2     Butaritari      KI   3.0707  172.7902     81.66        80          64
# 3          Tiksi      RU  71.6872  128.8694    -10.16        99          32
# 4    East London      ZA -33.0153   27.9116     68.94        83           0
# ..           ...     ...      ...       ...       ...       ...         ...
# 686       Ialibu      PG  -6.2821  143.9935     63.23        83         100
# 687        Aktau      KZ  43.6500   51.2000     28.98        65          99
# 688     Misratah      LY  32.3754   15.0925     52.09        61           0
# 689     Show Low      US  34.2542 -110.0298     34.14        46           0
# 690  Peace River      CA  56.2501 -117.2860     34.11        69         100
#
#      Wind Speed Current Description
# 0          1.99       broken clouds
# 1         18.52     overcast clouds
# 2         17.58       broken clouds
# 3          6.49    scattered clouds
# 4          6.91           clear sky
# ..          ...                 ...
# 686        3.74     overcast clouds
# 687        6.24     overcast clouds
# 688       15.90           clear sky
# 689        0.00           clear sky
# 690        9.22     overcast clouds
#
# [691 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
import numpy as np

# 7. Drop the rows where there is no Hotel Name.

c = hotel_df.replace(r'^\s*$', np.nan, regex=True)
clean_hotel_df = c.dropna()
clean_hotel_df.head()
